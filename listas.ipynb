# %% [markdown]
# # 📊 Exercícios de Listas - Python
#
# Este notebook contém exercícios focados em **listas**.
#
# **Temas abordados:**
# - 📊 Criação e manipulação de listas
# - 📊 Métodos de lista (append, remove, sort, etc)
# - 📊 List comprehension
# - 📊 Fatiamento de listas
# - 📊 Iteração em listas
#
# **Vamos praticar!** 🚀

# %% [markdown]
# ## Exercício 1: Criando Listas
# Crie uma lista com os números de 1 a 10 e imprima-a.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 2: Acessando Elementos
# Crie uma lista com 5 frutas e imprima o primeiro, o último e o terceiro elemento.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 3: Adicionando Elementos
# Crie uma lista vazia e adicione os números 1, 2, 3 usando append. Depois adicione o número 0 no início usando insert.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 4: Removendo Elementos
# Crie uma lista com os números [1, 2, 3, 4, 5, 3] e remova:
# - O número 3 usando remove
# - O último elemento usando pop
# - O primeiro elemento usando del

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 5: Ordenando Listas
# Crie uma lista com números aleatórios e ordene em ordem crescente e decrescente.

# %%
# Seu código aqui
import random

# %% [markdown]
# ## Exercício 6: Soma de Elementos
# Crie uma função que recebe uma lista de números e retorna a soma de todos os elementos.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 7: Maior e Menor
# Crie uma função que recebe uma lista e retorna o maior e o menor elemento.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 8: Contando Elementos
# Crie uma função que conta quantas vezes um determinado elemento aparece em uma lista.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 9: Fatiamento
# Crie uma lista com 10 números e:
# - Imprima os 3 primeiros
# - Imprima os 3 últimos
# - Imprima do índice 2 ao 7

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 10: Lista de Pares
# Use list comprehension para criar uma lista com todos os números pares de 1 a 50.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 11: Lista de Quadrados
# Use list comprehension para criar uma lista com o quadrado de cada número de 1 a 10.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 12: Unindo Listas
# Crie duas listas e una-as em uma terceira lista de duas formas diferentes: usando + e usando extend.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 13: Lista de Nomes
# Crie uma lista de nomes e filtre apenas os nomes que começam com a letra 'A'.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 14: Invertendo Lista
# Crie uma função que inverte uma lista sem usar o método reverse ou [::-1].

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 15: Remover Duplicatas
# Crie uma função que recebe uma lista com duplicatas e retorna uma lista sem elementos repetidos.

# %%
# Seu código aqui
