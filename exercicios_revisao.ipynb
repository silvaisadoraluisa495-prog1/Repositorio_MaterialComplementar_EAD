# %% [markdown]
# # 🎮 Lista de Exercícios
#
# Bem-vindo(a) ao mundo da programação! Estes exercícios foram criados pensando em você, com temas que vão desde jogos até redes sociais.
#
# **O que você vai praticar:**
# - 🎯 Funções
# - 🔄 Loopings (for, while)
# - ⚡ Condicionais (if, elif, else)
# - 📊 Listas e Dicionários
#
# **Bora codar!** 🚀

# %% [markdown]
# ## Exercício 1: 🎮 Detector de Nível do Gamer
# Crie uma função que recebe as horas jogadas por dia e classifica o gamer:
# - Menos de 2h: 'Casual'
# - 2h a 5h: 'Dedicado'
# - Mais de 5h: 'No-Life' 🏆

# %%
# Seu código aqui
def nivel_gamer(horas):
    # Implemente a função
    pass

# Teste sua função
print(nivel_gamer(1.5))  # Deve retornar 'Casual'
print(nivel_gamer(3))    # Deve retornar 'Dedicado'
print(nivel_gamer(6))    # Deve retornar 'No-Life'

# %% [markdown]
# ## Exercício 2: 🔢 Calculadora de XP
# Crie uma função que calcula o XP (experiência) de um personagem. Cada missão completada dá 100 XP e cada boss derrotado dá 500 XP. A função deve receber o número de missões e bosses e retornar o XP total.

# %%
# Seu código aqui
def calcular_xp(missoes, bosses):
    # Implemente a função
    pass

# Teste sua função
print(calcular_xp(3, 2))  # Deve retornar 1300 (3*100 + 2*500)

# %% [markdown]
# ## Exercício 3: 📱 Stories do Instagram
# Você postou stories e quer saber quantas pessoas viram todos. Crie uma função que recebe uma lista com os nomes das pessoas que viram cada story e retorna quem viu todos (interseção entre as listas).

# %%
# Seu código aqui
def quem_viu_tudo(story1, story2, story3):
    # Implemente a função
    pass

# Teste sua função
story1 = ['Ana', 'João', 'Maria', 'Pedro']
story2 = ['Ana', 'João', 'Carlos', 'Maria']
story3 = ['Ana', 'Maria', 'Pedro', 'João']
print(quem_viu_tudo(story1, story2, story3))  # Deve retornar ['Ana', 'João', 'Maria']

# %% [markdown]
# ## Exercício 4: 🎵 Playlist do Spotify
# Crie uma função que recebe uma lista de músicas e retorna quantas horas de música você tem. Cada música dura em média 3 minutos e 30 segundos.

# %%
# Seu código aqui
def horas_de_musica(musicas):
    # Implemente a função
    pass

# Teste sua função
playlist = ['Música1', 'Música2', 'Música3', 'Música4', 'Música5']
print(horas_de_musica(playlist))  # Deve retornar 0.29 horas (5 * 3.5 minutos = 17.5 minutos = 0.29 horas)

# %% [markdown]
# ## Exercício 5: 🏆 Sistema de Ranking
# Crie uma função que recebe uma lista de pontuações e retorna a posição de cada jogador no ranking. Use loop para percorrer a lista.

# %%
# Seu código aqui
def ranking(pontuacoes):
    # Implemente a função
    pass

# Teste sua função
pontos = [1500, 2300, 1800, 3000, 2100]
print(ranking(pontos))  # Deve retornar algo como [4, 2, 3, 1, 5] (posições)
# O jogador com 3000 é o 1º, 2300 é o 2º, 2100 é o 3º, 1800 é o 4º, 1500 é o 5º

# %% [markdown]
# ## Exercício 6: 💬 Gerador de Memes
# Crie uma função que recebe um texto e o transforma em meme, alternando entre maiúsculas e minúsculas. Exemplo: "bora codar" -> "BoRa CoDaR"

# %%
# Seu código aqui
def gerar_meme(texto):
    # Implemente a função
    pass

# Teste sua função
print(gerar_meme('bora codar'))  # Deve retornar 'BoRa CoDaR'
print(gerar_meme('python é top'))  # Deve retornar 'PyThOn É ToP'

# %% [markdown]
# ## Exercício 7: 🎯 Sistema de Vidas em Jogo
# Crie um jogo simples onde o jogador começa com 5 vidas. A cada erro ele perde uma vida. Quando chegar a 0 vidas, mostra "Game Over!". Use um loop while para simular as tentativas.

# %%
# Seu código aqui
def jogo_das_vidas():
    # Implemente a função
    pass

# Teste sua função
jogo_das_vidas()

# %% [markdown]
# ## Exercício 8: 📱 Filtro do TikTok
# Crie uma função que recebe uma lista de vídeos com suas visualizações e retorna apenas os vídeos com mais de 1000 visualizações (vídeos virais).

# %%
# Seu código aqui
def filtrar_virais(videos, visualizacoes):
    # Implemente a função
    pass

# Teste sua função
videos = ['Dance', 'Comedia', 'Tutorial', 'Desafio', 'Gameplay']
visualizacoes = [500, 2000, 800, 1500, 300]
print(filtrar_virais(videos, visualizacoes))  # Deve retornar ['Comedia', 'Desafio']

# %% [markdown]
# ## Exercício 9: 🎨 Mix de Cores
# Crie uma função que recebe duas cores primárias (vermelho, amarelo, azul) e retorna a cor resultante da mistura:
# - Vermelho + Amarelo = Laranja
# - Vermelho + Azul = Roxo
# - Amarelo + Azul = Verde

# %%
# Seu código aqui
def misturar_cores(cor1, cor2):
    # Implemente a função
    pass

# Teste sua função
print(misturar_cores('vermelho', 'amarelo'))  # Deve retornar 'Laranja'
print(misturar_cores('azul', 'vermelho'))     # Deve retornar 'Roxo'

# %% [markdown]
# ## Exercício 10: 🎲 Simulador de Dados
# Crie uma função que simula o lançamento de 2 dados (valores de 1 a 6) e retorna a soma. Use o loop para lançar os dados N vezes e calcular a média das somas.

# %%
# Seu código aqui
import random
def simulador_dados(n):
    # Implemente a função
    pass

# Teste sua função
print(simulador_dados(10))  # Deve retornar a média das somas de 10 lançamentos

# %% [markdown]
# ## Exercício 11: 📸 Like ou Deslike?
# Crie uma função que recebe o número de likes e deslikes de um vídeo e retorna se ele é 'Popular' (mais likes que deslikes), 'Controverso' (likes e deslikes quase iguais) ou 'Flop' (mais deslikes que likes).

# %%
# Seu código aqui
def analisar_video(likes, deslikes):
    # Implemente a função
    pass

# Teste sua função
print(analisar_video(100, 20))   # Deve retornar 'Popular'
print(analisar_video(50, 45))    # Deve retornar 'Controverso'
print(analisar_video(10, 90))    # Deve retornar 'Flop'

# %% [markdown]
# ## Exercício 12: 🧮 Progressão de Nível
# Crie uma função que calcula o nível de um personagem baseado no XP. A fórmula é: nível = XP // 100 + 1. Use um loop para mostrar o XP necessário para cada nível até o nível 10.

# %%
# Seu código aqui
def niveis_ate_10():
    # Implemente a função
    pass

# Teste sua função
niveis_ate_10()  # Deve mostrar: Nível 1: 0 XP, Nível 2: 100 XP, ...

# %% [markdown]
# ## Exercício 13: 🎬 Recomendação de Filmes
# Crie uma função que recebe o gênero favorito e recomenda um filme:
# - 'Ação': 'Velozes e Furiosos'
# - 'Comédia': 'Todo Mundo em Pânico'
# - 'Terror': 'Invocação do Mal'
# - 'Animação': 'Toy Story'
# - Outros: 'Recomendamos um clássico!'

# %%
# Seu código aqui
def recomendar_filme(genero):
    # Implemente a função
    pass

# Teste sua função
print(recomendar_filme('Ação'))      # Deve retornar 'Velozes e Furiosos'
print(recomendar_filme('Drama'))     # Deve retornar 'Recomendamos um clássico!'

# %% [markdown]
# ## Exercício 14: 📊 Estatísticas do Twitch
# Crie uma função que recebe uma lista de números de espectadores de um streamer durante 5 dias e retorna:
# - Média de espectadores
# - Maior pico
# - Menor número de espectadores

# %%
# Seu código aqui
def estatisticas_twitch(espectadores):
    # Implemente a função
    pass

# Teste sua função
dados = [1200, 850, 2000, 1500, 3000]
print(estatisticas_twitch(dados))  # Deve retornar (1710, 3000, 850)

# %% [markdown]
# ## Exercício 15: 🎮 Código Secreto
# Crie um jogo onde o computador escolhe um número secreto entre 1 e 100, e o jogador tem que adivinhar. A cada tentativa, o programa dá dicas se é 'Muito alto', 'Muito baixo' ou 'Acertou!'. Use um loop while.

# %%
# Seu código aqui
import random
def jogo_adivinhacao():
    # Implemente a função
    pass

# Teste sua função
jogo_adivinhacao()
