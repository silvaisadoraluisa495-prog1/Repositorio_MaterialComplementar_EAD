# %% [markdown]
# # ⚡ Exercícios de Condicionais - Python
#
# Este notebook contém exercícios focados em **estruturas condicionais** (if, elif, else).
#
# **Temas abordados:**
# - ⚡ If, elif, else
# - ⚡ Operadores de comparação
# - ⚡ Operadores lógicos (and, or, not)
# - ⚡ Condicionais aninhados
#
# **Vamos praticar!** 🚀

# %% [markdown]
# ## Exercício 1: Par ou Ímpar
# Peça ao usuário um número e diga se ele é par ou ímpar.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 2: Positivo, Negativo ou Zero
# Peça ao usuário um número e classifique como positivo, negativo ou zero.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 3: Maior de 3 Números
# Peça 3 números ao usuário e diga qual é o maior.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 4: Classificação de Notas
# Peça uma nota (0 a 100) e classifique como:
# - A: 90-100
# - B: 80-89
# - C: 70-79
# - D: 60-69
# - F: 0-59

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 5: Ano Bissexto
# Peça um ano e diga se ele é bissexto.
# Regras: Ano divisível por 4, mas não por 100, ou divisível por 400.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 6: IMC
# Peça peso e altura, calcule o IMC e classifique:
# - Abaixo do peso: < 18.5
# - Peso normal: 18.5 - 24.9
# - Sobrepeso: 25 - 29.9
# - Obesidade: >= 30

# %%
# Seu código aqui
# IMC = peso / (altura ** 2)

# %% [markdown]
# ## Exercício 7: Login Simples
# Crie um sistema de login com usuário e senha fixos. Se o usuário for 'admin' e senha '1234', mostre 'Acesso permitido', senão 'Acesso negado'.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 8: Triângulo
# Peça 3 lados e diga se formam um triângulo e qual tipo:
# - Equilátero: todos os lados iguais
# - Isósceles: dois lados iguais
# - Escaleno: todos os lados diferentes
#
# Regra: soma de dois lados sempre maior que o terceiro.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 9: Calculadora Simples
# Crie uma calculadora que recebe dois números e uma operação (+, -, *, /) e mostra o resultado. Trate divisão por zero.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 10: Votação
# Peça a idade e diga se a pessoa pode votar:
# - 16-17: Voto facultativo
# - 18-70: Voto obrigatório
# - +70: Voto facultativo
# - <16: Não pode votar

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 11: Ordem Crescente
# Peça 3 números e os coloque em ordem crescente usando condicionais.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 12: Pedra, Papel ou Tesoura
# Crie um jogo de Pedra, Papel ou Tesoura onde o usuário joga contra o computador.
# Regras: Pedra ganha de Tesoura, Tesoura ganha de Papel, Papel ganha de Pedra.

# %%
# Seu código aqui
import random
