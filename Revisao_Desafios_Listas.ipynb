# %% [markdown]
# # 🐍 Python Básico: Exercícios Divertidos
# ## Listas, Loops e Strings para Jovens Programadores
#
# **Instruções:** Resolva cada exercício no espaço indicado. Divirta-se!

# %% [markdown]
# ### 📝 Exercício 1: Playlist Musical
# Você tem uma playlist com 5 músicas. Crie uma lista chamada `playlist` com seus artistas favoritos e use um loop `for` para mostrar cada música no formato: "Tocando agora: [artista]"

# %%
# Seu código aqui
playlist = ["Billie Eilish", "Bad Bunny", "Taylor Swift", "Drake", "Olivia Rodrigo"]

# %% [markdown]
# ### 🎮 Exercício 2: Gírias de Jogador
# Crie uma lista `girias_gamer` com pelo menos 5 gírias de jogos (ex: "noob", "GG", "rage quit"). Use um loop para transformar todas em MAIÚSCULAS e mostre o resultado.

# %%
# Seu código aqui
girias_gamer = ["noob", "gg", "rage quit", "nerf", "buff"]

# %% [markdown]
# ### 📱 Exercício 3: Hashtags do TikTok
# Você quer criar hashtags para seus vídeos. Crie uma função que receba uma frase e retorne ela no formato hashtag: sem espaços e com # no início. Exemplo: "dance challenge" → "#dancechallenge"

# %%
# Seu código aqui
def criar_hashtag(frase):
    return "#" + frase.replace(" ", "")

# Teste
print(criar_hashtag("dance challenge"))
print(criar_hashtag("viral video"))

# %% [markdown]
# ### 🏀 Exercício 4: Estatísticas do Jogador
# Crie uma lista com os pontos que um jogador de basquete fez em 7 jogos: `[18, 24, 15, 30, 22, 19, 27]`. Calcule e mostre:
# - Total de pontos
# - Média de pontos
# - Melhor pontuação

# %%
# Seu código aqui
pontos = [18, 24, 15, 30, 22, 19, 27]

# %% [markdown]
# ### 🎬 Exercício 5: Contador de Séries
# Você está maratonando séries! Crie um programa que conte de 1 até o número de episódios que você quer assistir. Para cada episódio, mostre: "Assistindo episódio X". Se for o último episódio, mostre também "🏁 Final da temporada!"

# %%
# Seu código aqui

# %% [markdown]
# ### 💬 Exercício 6: Contador de Likes
# Você recebeu comentários em seu post e quer contar quantas vezes aparece a palavra "like". Dada a string: `"Like, muito like nesse post! Super like!"`, conte quantos "like" existem (case insensitive).

# %%
# Seu código aqui

# %% [markdown]
# ### 👕 Exercício 7: Loja de Streetwear
# Crie uma lista `estoque_roupas` com peças de roupa. O usuário digita uma peça e o programa verifica se está disponível na loja. Mostre "Disponível! 🔥" ou "Esgotado! 😢"

# %%
# Seu código aqui

# %% [markdown]
# ### 🎵 Exercício 8: Gerador de Nome de Banda
# Crie um programa que peça o nome da sua cidade e seu animal de estimação. Junte as duas palavras (primeira metade de cada) para criar o nome da sua banda!

# %%
# Seu código aqui

# %% [markdown]
# ### 🎮 Exercício 9: Ranking de Games
# Crie uma lista `jogos_favoritos` com seus 5 jogos preferidos em ordem. Use um loop for com `enumerate()` para mostrar o ranking no formato: "1º lugar: [jogo] ⭐"

# %%
# Seu código aqui

# %% [markdown]
# ### ✍️ Exercício 10: Filtro de Palavrões
# Crie um programa que substitua palavras indesejadas em um texto. Dada a frase: "Esse jogo é muito ruim e chato", substitua "ruim" e "chato" por "****" e mostre o texto censurado.

# %%
# Seu código aqui

# %% [markdown]
# ### 📊 Exercício 11: Notas Escolares
# Crie uma lista com suas notas do bimestre: `[7.5, 8.0, 6.5, 9.0]`. Calcule a média e mostre se você passou (média ≥ 7) ou se precisa estudar mais.

# %%
# Seu código aqui

# %% [markdown]
# ### 🎨 Exercício 12: Inversor de Emojis
# Crie uma string com emojis: `"😀🎮🎵🌟💻"` e mostre ela invertida usando string slicing.

# %%
# Seu código aqui

# %% [markdown]
# ### 🎤 Exercício 13: Sorteio de Karaokê
# Crie uma lista `amigos` com nomes. Use `random.choice()` para sortear quem vai cantar primeiro no karaokê.

# %%
# Seu código aqui

# %% [markdown]
# ### 📸 Exercício 14: Filtro do Instagram
# Crie um programa que peça uma legenda para foto e:
# - Mostre quantos caracteres tem
# - Transforme em letras minúsculas
# - Substitua os espaços por underscores
# Exemplo: "Viagem na Praia" → "viagem_na_praia" (21 caracteres)

# %%
# Seu código aqui

# %% [markdown]
# ### 🏆 Exercício 15: Top 3 Melhores Momentos
# Crie uma lista com momentos especiais do ano: `["formatura", "viagem", "show", "praia", "aniversário"]`. Use um loop for com `break` para mostrar apenas os 3 primeiros momentos (como se fosse um top 3).

# %%
# Seu código aqui

# %% [markdown]
# ## 🎉 Parabéns!
# Você completou todos os 15 exercícios! Agora você está mais preparado para programar em Python.
#
# **Desafio extra:** Crie seu próprio exercício baseado nos temas que você mais gostou e compartilhe com um amigo!
