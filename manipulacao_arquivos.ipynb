# %% [markdown]
# # 📁 Exercícios de Manipulação de Arquivos - Python
#
# Este notebook contém exercícios focados em **manipulação de arquivos**.
#
# **Temas abordados:**
# - 📁 Leitura de arquivos
# - 📁 Escrita em arquivos
# - 📁 Anexar dados em arquivos
# - 📁 Trabalhando com CSV
# - 📁 Tratamento de erros (try/except)
#
# **Vamos praticar!** 🚀

# %% [markdown]
# ## Exercício 1: Escrevendo em um Arquivo
# Crie um programa que escreve a frase 'Olá, mundo!' em um arquivo chamado 'hello.txt'.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 2: Lendo um Arquivo
# Crie um programa que lê e imprime o conteúdo do arquivo 'hello.txt' criado no exercício anterior.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 3: Escrevendo Múltiplas Linhas
# Crie um programa que escreve 5 linhas de texto em um arquivo chamado 'linhas.txt'.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 4: Lendo Linha por Linha
# Crie um programa que lê o arquivo 'linhas.txt' linha por linha e imprime cada uma.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 5: Anexando ao Arquivo
# Crie um programa que adiciona mais uma linha ao final do arquivo 'linhas.txt'.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 6: Arquivo de Números
# Crie um programa que escreve os números de 1 a 10 em um arquivo chamado 'numeros.txt', um por linha.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 7: Soma dos Números do Arquivo
# Crie um programa que lê o arquivo 'numeros.txt', soma todos os números e imprime o resultado.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 8: Arquivo de Nomes
# Crie um programa que pede ao usuário 5 nomes e os escreve em um arquivo chamado 'nomes.txt'.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 9: Lendo Nomes e Contando
# Crie um programa que lê o arquivo 'nomes.txt' e conta quantos nomes começam com a letra 'A'.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 10: Arquivo CSV
# Crie um programa que escreve dados em formato CSV (nome, idade, cidade) em um arquivo 'dados.csv'.

# %%
# Seu código aqui
# Exemplo de dados: Ana,25,São Paulo

# %% [markdown]
# ## Exercício 11: Lendo CSV
# Crie um programa que lê o arquivo 'dados.csv' e imprime cada linha formatada.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 12: Copiando Arquivo
# Crie um programa que copia o conteúdo de 'hello.txt' para um novo arquivo chamado 'hello_copy.txt'.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 13: Contador de Palavras
# Crie um programa que lê um arquivo de texto e conta o número total de palavras.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 14: Tratamento de Erros
# Crie um programa que tenta abrir um arquivo que não existe e usa try/except para mostrar uma mensagem de erro amigável.

# %%
# Seu código aqui

# %% [markdown]
# ## Exercício 15: Log de Atividades
# Crie um programa que registra atividades em um arquivo de log. Cada atividade deve ter data/hora e descrição.

# %%
# Seu código aqui
import datetime
